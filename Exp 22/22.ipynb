# %%
# !pip install pandas openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd

# Load data from CSV
csv_file_path = '"D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data_500.csv"'   # Make sure this file exists in your folder
df_csv = pd.read_csv("D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data_500.csv")

# Display the DataFrame
print("📘 CSV Data:")
print(df_csv)

# Basic data manipulation: Filter by Age > 30
filtered_data = df_csv[df_csv['Age'] > 30]
print("\n📘 Filtered Data (Age > 30):")
print(filtered_data)
# Out:
# 📘 CSV Data:
#         Name  Age          City
# 0      Grace   25      New York
# 1     Xavier   35       Phoenix
# 2        Bob   39  Jacksonville
# 3      Kabir   44  Jacksonville
# 4    Charlie   50   San Antonio
# ..       ...  ...           ...
# 495    Alice   36      San Jose
# 496    Kabir   23  Indianapolis
# 497    Wendy   39       Chicago
# 498    Laura   30        Denver
# 499     Mike   39    Washington
#
# [500 rows x 3 columns]
#
# 📘 Filtered Data (Age > 30):
#         Name  Age          City
# 1     Xavier   35       Phoenix
# 2        Bob   39  Jacksonville
# 3      Kabir   44  Jacksonville
# 4    Charlie   50   San Antonio
# 5       Yara   43        Denver
# ..       ...  ...           ...
# 491      Eve   51      Columbus
# 492    David   60  Philadelphia
# 495    Alice   36      San Jose
# 497    Wendy   39       Chicago
# 499     Mike   39    Washington
#
# [345 rows x 3 columns]
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# ...

# %%
# Load data from JSON
json_file_path = 'D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.json'
df_json = pd.read_json("D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.json")

# Display DataFrame
print("\n📗 JSON Data:")
print(df_json)

# Basic data manipulation: Find the average age
average_age = df_json['Age'].mean()
print("\n📗 Average Age:", average_age)
# Out:
# 📗 JSON Data:
#     Name  Age           City
# 0  David   28  San Francisco
# 1    Eve   22        Seattle
#
# 📗 Average Age: 25.0
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\shivk\AppData\Local\Temp\ipykernel_33788\2074031286.py:2: SyntaxWarning: invalid escape sequence '\D'
#   json_file_path = 'D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.json'
# C:\Users\shivk\AppData\Local\Temp\ipykernel_33788\2074031286.py:3: SyntaxWarning: invalid escape sequence '\D'
#   df_json = pd.read_json("D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.json")

# %%
# Load data from Excel
excel_file_path = '"D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.xlsx"'
df_excel = pd.read_excel("D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.xlsx")

# Display DataFrame
print("\n📙 Excel Data:")
print(df_excel)

# Basic data manipulation: Count number of entries
entry_count = df_excel.shape[0]
print("\n📙 Number of entries in Excel file:", entry_count)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\shivk\AppData\Local\Temp\ipykernel_33788\4112266968.py:2: SyntaxWarning: invalid escape sequence '\D'
#   excel_file_path = '"D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.xlsx"'
# C:\Users\shivk\AppData\Local\Temp\ipykernel_33788\4112266968.py:3: SyntaxWarning: invalid escape sequence '\D'
#   df_excel = pd.read_excel("D:\Degree Sem 3\PWP\Lab Task\python\Exp 22\sample_data.xlsx")
# 📙 Excel Data:
#              Name Relation             Email         Phone            Notes
# 0  Shivkumar Paun     Self  shiv@example.com  9.251013e+10  Primary contact
# 1     Mother Name   Mother               NaN           NaN      Add details
# 2     Father Name   Father               NaN           NaN      Add details
#
# 📙 Number of entries in Excel file: 3

# %%
# Save filtered CSV data
filtered_data.to_csv('filtered_data.csv', index=False)
print("\n💾 Filtered data saved to 'filtered_data.csv'.")

# Save JSON data to a new file
df_json.to_json('new_data.json', orient='records', lines=True)
print("💾 JSON data saved to 'new_data.json'.")

# Save Excel data to a new file
df_excel.to_excel('new_data.xlsx', index=False)
print("💾 Excel data saved to 'new_data.xlsx'.")
# Out:
# 💾 Filtered data saved to 'filtered_data.csv'.
# 💾 JSON data saved to 'new_data.json'.
# 💾 Excel data saved to 'new_data.xlsx'.
