# %%
# Aim: Audio Processing using Python
# ---------------------------------
# We'll read, write, visualize, and apply basic effects to audio files.

print("🎯 Experiment: Audio Processing using Python")
print("Libraries used: soundfile, matplotlib, numpy, pydub")
# Out:
# 🎯 Experiment: Audio Processing using Python
# Libraries used: soundfile, matplotlib, numpy, pydub

# %%
# Run this cell once to install necessary packages inside the environment
# !pip install soundfile matplotlib numpy pydub
# Out:
# Collecting soundfile
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: pydub in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (0.25.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\shivk\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Installing collected packages: soundfile
# Successfully installed soundfile-0.13.1

# %%
import soundfile as sf

# Load your audio file (update the path below)
audio, sample_rate = sf.read(r"C:\Users\shivk\Downloads\9df1c550ea5744e3a4fe87816570f260.mp3")

print("✅ Audio loaded successfully!")
print("Shape:", audio.shape)
print("Sample Rate:", sample_rate)

# Write it back as a new file
sf.write('new_audio_file.wav', audio, sample_rate)
print("💾 Saved: new_audio_file.wav")
# Out:
# ✅ Audio loaded successfully!
# Shape: (1250437,)
# Sample Rate: 24000
# 💾 Saved: new_audio_file.wav

# %%
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf

# Load again (optional)
audio, sample_rate = sf.read(r"C:\Users\shivk\Downloads\9df1c550ea5744e3a4fe87816570f260.mp3")

# Create time axis (seconds)
time = np.arange(0, len(audio)) / sample_rate

# Plot waveform
plt.figure(figsize=(10,4))
plt.plot(time, audio, color='purple')
plt.title("Audio Signal in Time Domain")
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()

# %%
from pydub import AudioSegment

# Load audio (Pydub works with file paths)
audio = AudioSegment.from_file(r"C:\Users\shivk\Downloads\9df1c550ea5744e3a4fe87816570f260.mp3")

# Apply 2-second fade-in
audio_fade_in = audio.fade_in(2000)

# Save result
audio_fade_in.export("audio_file_fade_in.wav", format="wav")

print("✨ Fade-in effect applied and saved as audio_file_fade_in.wav")
