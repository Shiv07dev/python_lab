# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\degree sem 3\pwp\lab task\python\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="white")

# %%
rs = np.random.RandomState(15)
data = rs.normal(size=120)

sns.histplot(data, kde=True, color="purple")
plt.title("Histogram with KDE")
plt.show()

# %%
sns.distplot(data, color="darkblue")
plt.title("Distplot of Data")
plt.show()
# Out:
# C:\Users\shivk\AppData\Local\Temp\ipykernel_15496\3199470959.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, color="darkblue")

# %%
sns.set(style="darkgrid")
fmri = sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y="signal", hue="region", style="event", data=fmri)
plt.title("FMRI Signal Over Time")
plt.show()

# %%
sns.set(style="ticks")
anscombe = sns.load_dataset("anscombe")

sns.lmplot(x="x", y="y", data=anscombe)
plt.title("Linear Regression Plot")
plt.show()
